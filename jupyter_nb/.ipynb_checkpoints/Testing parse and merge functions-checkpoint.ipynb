# %%
# %matplotlib tk
import matplotlib
from matplotlib import pyplot as plt
#matplotlib.use('tkAgg')
import sys
sys.path.append('../')
import parse_pws_data as parsePWS
import pandas as pd

# %%
#reading a raw text file and writing a .csv with the same name in the same folder
parsePWS.merge_csv(inDir='/home/uibk/DATA/02_data/wunderground/test/TEST2022/ITIROLAX2_CSV/', outfile='/home/uibk/DATA/02_data/wunderground/test/TEST2022/ITIROLAX2_CSV/Merged_CSV.csv')

# %%
dat=pd.read_csv('/home/uibk/DATA/02_data/wunderground/test/TEST2022/ITIROLAX2_CSV/Merged_CSV.csv',sep=';',index_col='datetime',
                na_values=['NaN',-9999])

# %%
dat
# Out:
#                       temp  dewPoint  humidity   wDir  wAvg  wGust  pressure  \
# datetime
# 2022-06-15 00:04:00  13.89      1.11      0.04    SSW  0.00   0.00    763.02
# 2022-06-15 00:09:00  13.33      0.56      0.04  South  0.00   0.00    763.02
# 2022-06-15 00:14:00  13.33      1.11      0.04    SSW  0.00   0.00    763.02
# 2022-06-15 00:19:00  13.33      0.56      0.04    SSW  0.00   0.00    763.02
# 2022-06-15 00:24:00  13.33      0.56      0.04    SSW  0.00   0.00    763.02
# ...                    ...       ...       ...    ...   ...    ...       ...
# 2022-06-21 16:24:00  25.00      7.22      0.03     NE  2.41   4.51    757.94
# 2022-06-21 16:29:00  25.00      7.78      0.03     NW  2.25   4.51    757.94
# 2022-06-21 16:34:00  25.00      7.22      0.03   East  2.74   5.63    757.68
# 2022-06-21 16:39:00  25.00      6.67      0.03    NNE  3.70   6.76    757.68
# 2022-06-21 16:44:00  25.00      7.78      0.03    ENE  6.76  10.62    757.68
#
#                       pI  pCum
# ...

# %%
dat.pCum.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
